# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt

env_path = "/home/cstansbu/miniconda3/envs/scanpy/lib/python3.12/site-packages/"
sys.path.append(env_path)

import scanpy as sc

# %%
fpath = "/nfs/turbo/umms-indikar/shared/projects/HSC/data/weng_2024/scanpy_objects/Old1.BMMC_HSPC.Seurat.h5ad"

adata = sc.read_h5ad(fpath)
adata
# Out:
# AnnData object with n_obs × n_vars = 14917 × 36601
#     obs: 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nCount_SCT', 'nFeature_SCT', 'SCT.weight', 'ATAC.weight', 'wsnn_res.0.8', 'seurat_clusters', 'Sig.HSC1', 'Sig.Prog1', 'Sig.EarlyE1', 'Sig.LateE1', 'Sig.ProMono1', 'Sig.Mono1', 'Sig.ncMono1', 'Sig.cDC1', 'Sig.pDC1', 'Sig.ProB1', 'Sig.PreB1', 'Sig.B1', 'Sig.Plasma1', 'Sig.T1', 'Sig.CTL1', 'Sig.NK1', 'Origin.Seurat', 'STD.CellType', 'STD_Cat', 'STD_Cat2', 'Sample', 'MitoCoverage', 'ClonalGroup'
#     var: 'name'
#     obsm: 'X_lsi', 'X_pca', 'X_umap.atac', 'X_umap.rna', 'X_wnn.umap'

# %%
adata.obs.head()
# Out:
#                     nCount_RNA  nFeature_RNA  nCount_ATAC  nFeature_ATAC  \
# AAACAGCCAAAGGCCA-2      3655.0          1855      22678.0           9940
# AAACAGCCAATGCCTA-2      6652.0          2901       9850.0           4831
# AAACAGCCAATTTGGT-1      1695.0          1094       9270.0           4365
# AAACAGCCAGCTTAAT-2      2783.0          1592       6339.0           3073
# AAACAGCCAGGATGGC-1      2053.0          1272       5536.0           2704
#
#                     nCount_SCT  nFeature_SCT  SCT.weight  ATAC.weight  \
# AAACAGCCAAAGGCCA-2      3144.0          1851    0.511303     0.488697
# AAACAGCCAATGCCTA-2      2945.0          1780    0.537865     0.462135
# AAACAGCCAATTTGGT-1      2121.0          1093    0.545676     0.454324
# AAACAGCCAGCTTAAT-2      2763.0          1592    0.498380     0.501620
# AAACAGCCAGGATGGC-1      2187.0          1272    0.591055     0.408945
#
#                    wsnn_res.0.8 seurat_clusters  ...    Sig.T1  Sig.CTL1  \
# ...

# %%
adata.obsm['X_umap'] = adata.obsm['X_umap.rna']

# %%
sc.pl.umap(adata, color='STD.CellType')

# %%
# ?sc.pl.umap

# %%
break
# Out:
#   Cell In[12], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# # Playground
