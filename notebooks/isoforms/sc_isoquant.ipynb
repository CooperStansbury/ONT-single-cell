# %%
import numpy as np
import pandas as pd
import pyranges as pr
import gget
import glob
import os
import time
import psutil
import re
import seaborn as sns
import matplotlib.pyplot as plt
from importlib import reload

# %% [markdown]
# # Load gene mapping

# %%
fpath = "/scratch/indikar_root/indikar1/cstansbu/HSC/references/geneTable.csv"

gdf = pd.read_csv(fpath, low_memory=False)

gdf = gdf[gdf['gene_biotype'] == 'protein_coding']
gdf = gdf[gdf['gene_name'].notna()]

gene_map = gdf.drop_duplicates().set_index('gene_id')['gene_name'].to_dict()
transcript_map = gdf.drop_duplicates().set_index('transcript_id')['transcript_name'].to_dict()

print(f"{len(gene_map)=}")
print(f"{len(transcript_map)=}")
# Out:
# len(gene_map)=19401
# len(transcript_map)=167915

# %% [markdown]
# # Load read assignments

# %%
dpath = "/scratch/indikar_root/indikar1/cstansbu/HSC/isoquant/"

columns = ['isoform_id', 'gene_id']  # Removed redundant columns

# Define the extraction pattern
pattern = r'(?P<cell_id>\w+)_(?P<UMI>\w+)#(?P<read_name>[\w-]+).*'

df = []

print("Starting to process runs...")

for run_id in os.listdir(dpath):
    subdir_path = f"{dpath}{run_id}"
    if os.path.isdir(subdir_path) and run_id != 'output':
        read_path = f"{dpath}{run_id}/{run_id}.read_assignments.tsv.gz"

        start_time = time.time()  # Start timing for this run
        print(f"Loading data for run {run_id}...")

        tmp = pd.read_csv(read_path, sep='\t', skiprows=2, low_memory=False)

        print(f"Initial shape: {tmp.shape}, Memory Usage: {tmp.memory_usage(deep=True).sum() / (1024**3):.2f} GB")

        tmp = tmp[tmp['assignment_type'] == 'unique'][columns + ['#read_id']]
        tmp['run_id'] = run_id

        tmp[['cell_id', 'UMI', 'read_name']] = tmp['#read_id'].str.extract(pattern)
        tmp['read_name'] = tmp['read_name'].apply(lambda x: x.split("_")[0])
        
        # map genes 
        tmp['gene_name'] = tmp['gene_id'].map(gene_map)
        tmp['transcript_name'] = tmp['isoform_id'].map(transcript_map)

        # remove uneedded columns
        tmp = tmp.drop(columns=['#read_id'])
        
        # drop unmapped genes
        tmp = tmp[tmp['gene_name'].notna()]
        tmp = tmp[tmp['transcript_name'].notna()]

        print(f"Filtered shape: {tmp.shape}, Memory Usage: {tmp.memory_usage(deep=True).sum() / (1024**3):.2f} GB")

        df.append(tmp)

        end_time = time.time()
        elapsed_time = end_time - start_time
        print(f"Run {run_id} processed in {elapsed_time:.2f} seconds\n")

        # break  # Remove this if you want to process all runs

print("Concatenating results...")
df = pd.concat(df)

print(f"Concatenated shape: {df.shape}")

# dropping duplicates
df = df.drop_duplicates(subset=['isoform_id', 'gene_id', 'cell_id'])

print(f"Final shape: {df.shape}")
print(f"Final Memory Usage: {psutil.virtual_memory().used / (1024**3):.2f} GB")
print(df.head().to_string(index=False))  # Nicer formatting for the output
# Out:
# Starting to process runs...
# Loading data for run Run3x0418...
# Initial shape: (1030084, 9), Memory Usage: 0.84 GB
# Filtered shape: (125453, 8), Memory Usage: 0.07 GB
# Run Run3x0418 processed in 7.23 seconds
#
# Loading data for run P2r8a...
# Initial shape: (4150537, 9), Memory Usage: 3.27 GB
# Filtered shape: (1149118, 8), Memory Usage: 0.62 GB
# Run P2r8a processed in 31.04 seconds
#
# Loading data for run Run5x0314...
# Initial shape: (99393, 9), Memory Usage: 0.08 GB
# Filtered shape: (19497, 8), Memory Usage: 0.01 GB
# Run Run5x0314 processed in 0.77 seconds
#
# Loading data for run Gridr5...
# Initial shape: (7168486, 9), Memory Usage: 5.69 GB
# Filtered shape: (1386851, 8), Memory Usage: 0.75 GB
# Run Gridr5 processed in 52.48 seconds
#
# Loading data for run Gridr4...
# Initial shape: (13947275, 9), Memory Usage: 11.45 GB
# Filtered shape: (2007101, 8), Memory Usage: 1.08 GB
# Run Gridr4 processed in 103.95 seconds
#
# Loading data for run Run6x0314...
# Initial shape: (102506, 9), Memory Usage: 0.08 GB
# Filtered shape: (20240, 8), Memory Usage: 0.01 GB
# Run Run6x0314 processed in 0.85 seconds
#
# Loading data for run Run8x0426...
# Initial shape: (426389, 9), Memory Usage: 0.35 GB
# Filtered shape: (47082, 8), Memory Usage: 0.03 GB
# Run Run8x0426 processed in 3.14 seconds
#
# Loading data for run P2r8b...
# Initial shape: (3534909, 9), Memory Usage: 2.79 GB
# Filtered shape: (978111, 8), Memory Usage: 0.53 GB
# Run P2r8b processed in 27.35 seconds
#
# Loading data for run Run6x0426...
# Initial shape: (1192156, 9), Memory Usage: 0.97 GB
# Filtered shape: (137610, 8), Memory Usage: 0.07 GB
# Run Run6x0426 processed in 8.39 seconds
#
# Loading data for run Run2x0416...
# Initial shape: (1199275, 9), Memory Usage: 0.99 GB
# Filtered shape: (177659, 8), Memory Usage: 0.10 GB
# Run Run2x0416 processed in 8.70 seconds
#
# Loading data for run Gridr2...
# Initial shape: (20422645, 9), Memory Usage: 16.83 GB
# Filtered shape: (3034443, 8), Memory Usage: 1.63 GB
# Run Gridr2 processed in 160.83 seconds
#
# Loading data for run P2r8...
# Initial shape: (9074994, 9), Memory Usage: 7.16 GB
# Filtered shape: (2518966, 8), Memory Usage: 1.35 GB
# Run P2r8 processed in 69.06 seconds
#
# Loading data for run P2r8d...
# Initial shape: (2495029, 9), Memory Usage: 1.97 GB
# Filtered shape: (689601, 8), Memory Usage: 0.37 GB
# Run P2r8d processed in 18.66 seconds
#
# Loading data for run Run4x0314...
# Initial shape: (106897, 9), Memory Usage: 0.09 GB
# Filtered shape: (21219, 8), Memory Usage: 0.01 GB
# Run Run4x0314 processed in 0.87 seconds
#
# Loading data for run Run7x0426...
# Initial shape: (71493, 9), Memory Usage: 0.06 GB
# Filtered shape: (8316, 8), Memory Usage: 0.00 GB
# Run Run7x0426 processed in 0.55 seconds
#
# Loading data for run P2r8c...
# Initial shape: (980397, 9), Memory Usage: 0.77 GB
# Filtered shape: (272044, 8), Memory Usage: 0.15 GB
# Run P2r8c processed in 7.34 seconds
#
# Loading data for run Run3x0314...
# Initial shape: (101975, 9), Memory Usage: 0.08 GB
# Filtered shape: (20022, 8), Memory Usage: 0.01 GB
# Run Run3x0314 processed in 0.85 seconds
#
# Loading data for run P2r5...
# Initial shape: (43629027, 9), Memory Usage: 35.65 GB
# Filtered shape: (8288530, 8), Memory Usage: 4.45 GB
# Run P2r5 processed in 362.95 seconds
#
# Loading data for run Run1x0415...
# Initial shape: (430330, 9), Memory Usage: 0.35 GB
# Filtered shape: (64409, 8), Memory Usage: 0.03 GB
# Run Run1x0415 processed in 3.20 seconds
#
# Loading data for run P2r6...
# Initial shape: (34112885, 9), Memory Usage: 27.90 GB
# Filtered shape: (6483760, 8), Memory Usage: 3.48 GB
# Run P2r6 processed in 274.41 seconds
#
# Loading data for run P2r7...
# Initial shape: (34563796, 9), Memory Usage: 28.23 GB
# Filtered shape: (6498717, 8), Memory Usage: 3.49 GB
# Run P2r7 processed in 279.16 seconds
#
# Loading data for run Gridr3...
# Initial shape: (14492372, 9), Memory Usage: 11.92 GB
# Filtered shape: (2144975, 8), Memory Usage: 1.16 GB
# Run Gridr3 processed in 111.81 seconds
#
# Loading data for run Run4x0422...
# Initial shape: (1517387, 9), Memory Usage: 1.24 GB
# Filtered shape: (186782, 8), Memory Usage: 0.10 GB
# Run Run4x0422 processed in 10.85 seconds
#
# Loading data for run Run2x0313...
# Initial shape: (115854, 9), Memory Usage: 0.10 GB
# Filtered shape: (22487, 8), Memory Usage: 0.01 GB
# Run Run2x0313 processed in 0.93 seconds
#
# Loading data for run Run1x0312...
# Initial shape: (127958, 9), Memory Usage: 0.10 GB
# Filtered shape: (25463, 8), Memory Usage: 0.01 GB
# Run Run1x0312 processed in 1.00 seconds
#
# Loading data for run Run7x0315...
# Initial shape: (2457578, 9), Memory Usage: 2.03 GB
# Filtered shape: (528997, 8), Memory Usage: 0.29 GB
# Run Run7x0315 processed in 20.84 seconds
#
# Loading data for run Run9x0503...
# Initial shape: (810783, 9), Memory Usage: 0.66 GB
# Filtered shape: (91469, 8), Memory Usage: 0.05 GB
# Run Run9x0503 processed in 5.91 seconds
#
# Loading data for run Gridr1...
# Initial shape: (16490866, 9), Memory Usage: 13.59 GB
# Filtered shape: (2468730, 8), Memory Usage: 1.33 GB
# Run Gridr1 processed in 127.08 seconds
#
# Concatenating results...
# Concatenated shape: (39417652, 8)
# Final shape: (11404157, 8)
# Final Memory Usage: 43.64 GB
#      isoform_id         gene_id    run_id          cell_id          UMI                            read_name gene_name transcript_name
# ENST00000483767 ENSG00000188976 Run3x0418 TGTGGCGGTAACGGTG AAGTTTACCGGG b43c7b93-2130-42e0-a51d-2819bedeb593     NOC2L       NOC2L-204
# ENST00000483767 ENSG00000188976 Run3x0418 CTAACTTGTCGTCATA TTTTGGATCTTT 5887c2fa-b3bd-4a22-b3f8-4ce31b4e9d0d     NOC2L       NOC2L-204
# ENST00000483767 ENSG00000188976 Run3x0418 AAGATAGAGTTGGGAC AACGGGTCCTCT 050743c4-d895-45d6-b59a-c5232b6ac1b1     NOC2L       NOC2L-204
# ENST00000469563 ENSG00000188976 Run3x0418 TATACCTAGTCGGCCT AACGGTTAGCCG f24c150f-2a5a-4581-96a7-081d004d28c6     NOC2L       NOC2L-202
# ENST00000469563 ENSG00000188976 Run3x0418 TGTAAGCGTGTCATTG AAACTCTAACTT 166e19dc-cd7c-4ee2-b35e-eb3ceb455285     NOC2L       NOC2L-202

# %% [markdown]
# # Save the output

# %%
outpath = "/scratch/indikar_root/indikar1/cstansbu/HSC/isoforms/isoform_data.parquet"
df.to_parquet(outpath, index=False)
df.head()
# Out:
#          isoform_id          gene_id     run_id           cell_id  \
# 53  ENST00000483767  ENSG00000188976  Run3x0418  TGTGGCGGTAACGGTG
# 54  ENST00000483767  ENSG00000188976  Run3x0418  CTAACTTGTCGTCATA
# 55  ENST00000483767  ENSG00000188976  Run3x0418  AAGATAGAGTTGGGAC
# 65  ENST00000469563  ENSG00000188976  Run3x0418  TATACCTAGTCGGCCT
# 66  ENST00000469563  ENSG00000188976  Run3x0418  TGTAAGCGTGTCATTG
#
#              UMI                             read_name gene_name  \
# 53  AAGTTTACCGGG  b43c7b93-2130-42e0-a51d-2819bedeb593     NOC2L
# 54  TTTTGGATCTTT  5887c2fa-b3bd-4a22-b3f8-4ce31b4e9d0d     NOC2L
# 55  AACGGGTCCTCT  050743c4-d895-45d6-b59a-c5232b6ac1b1     NOC2L
# 65  AACGGTTAGCCG  f24c150f-2a5a-4581-96a7-081d004d28c6     NOC2L
# 66  AAACTCTAACTT  166e19dc-cd7c-4ee2-b35e-eb3ceb455285     NOC2L
#
#    transcript_name
# 53       NOC2L-204
# 54       NOC2L-204
# 55       NOC2L-204
# 65       NOC2L-202
# 66       NOC2L-202

# %%
break
# Out:
#   Cell In[5], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop
