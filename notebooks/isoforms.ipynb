# %%
import pandas as pd
import numpy as np
import scanpy as sc
import sys
import os
import pysam
import pyranges as pr
import rapidfuzz

import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.colors import LogNorm, Normalize

import utils as ut

# %%
# load marker gene sets
fpath = "/nfs/turbo/umms-indikar/shared/projects/spatial_transcriptomics/data/panglaodb/pandb.tsv.gz"
celltypes = [
    'Hematopoietic stem cells',
    'Fibroblasts',
]
cell_names = [
    'Fib',
    'HSC'
]
markers = ut.get_pangloa(fpath, celltypes, cell_names)
print(f"{markers.shape=}")
markers.head()
# Out:
# markers.shape=(263, 3)
#   gene_name  Fib  HSC
# 0     ABCB1  0.0  1.0
# 1     ABCG2  0.0  1.0
# 2      ABI3  1.0  0.0
# 3       ACE  0.0  1.0
# 4     ACKR3  1.0  0.0

# %%
# load the GTF
gtf_path = "/scratch/indikar_root/indikar1/cstansbu/HSC/references/annotations.gtf"
gf = pr.read_gtf(gtf_path)
gdf = gf.df
print(f"{gdf.shape=}")
print(gdf.columns)
gdf.head()
# Out:
# gdf.shape=(3371244, 26)
# Index(['Chromosome', 'Source', 'Feature', 'Start', 'End', 'Score', 'Strand',
#        'Frame', 'gene_id', 'gene_version', 'gene_name', 'gene_source',
#        'gene_biotype', 'transcript_id', 'transcript_version',
#        'transcript_name', 'transcript_source', 'transcript_biotype', 'tag',
#        'ccds_id', 'exon_number', 'exon_id', 'exon_version', 'protein_id',
#        'protein_version', 'transcript_support_level'],
#       dtype='object')
#   Chromosome          Source      Feature    Start      End Score Strand  \
# 0          1  ensembl_havana         gene  1471764  1497848     .      +
# 1          1  ensembl_havana   transcript  1471764  1497848     .      +
# 2          1  ensembl_havana         exon  1471764  1472089     .      +
# 3          1  ensembl_havana          CDS  1471884  1472089     .      +
# 4          1  ensembl_havana  start_codon  1471884  1471887     .      +
#
#   Frame          gene_id gene_version  ... transcript_source  \
# 0     .  ENSG00000160072           20  ...               NaN
# 1     .  ENSG00000160072           20  ...    ensembl_havana
# 2     .  ENSG00000160072           20  ...    ensembl_havana
# 3     0  ENSG00000160072           20  ...    ensembl_havana
# 4     0  ENSG00000160072           20  ...    ensembl_havana
#
#   transcript_biotype    tag ccds_id exon_number          exon_id exon_version  \
# 0                NaN    NaN     NaN         NaN              NaN          NaN
# 1     protein_coding  basic  CCDS30         NaN              NaN          NaN
# 2     protein_coding  basic  CCDS30           1  ENSE00003889014            1
# 3     protein_coding  basic  CCDS30           1              NaN          NaN
# 4     protein_coding  basic  CCDS30           1              NaN          NaN
#
#         protein_id protein_version transcript_support_level
# 0              NaN             NaN                      NaN
# 1              NaN             NaN                      NaN
# 2              NaN             NaN                      NaN
# 3  ENSP00000500094               1                      NaN
# 4              NaN             NaN                      NaN
#
# [5 rows x 26 columns]

# %%
# build the version ids
tdf = gdf[gdf['Feature'] == 'transcript']

columns = [
    'gene_name',
    'gene_biotype',
    'Chromosome', 
    'Start', 
    'End',
    'transcript_name', 
    'transcript_biotype',
    'transcript_id',
    'transcript_version',
]

tdf = tdf[columns].drop_duplicates()
tdf['tid'] = tdf['transcript_id'] + "." + tdf['transcript_version']
tdf['transcript_biotype_clean'] = tdf['transcript_biotype'].apply(lambda x: x.replace("_", " "))
print(f"{tdf.shape=}")
tdf.head()
# Out:
# tdf.shape=(251121, 11)
#    gene_name    gene_biotype Chromosome    Start      End transcript_name  \
# 1     ATAD3B  protein_coding          1  1471764  1497848      ATAD3B-206
# 38    ATAD3B  protein_coding          1  1478025  1497848      ATAD3B-203
# 53    ATAD3B  protein_coding          1  1479048  1482662      ATAD3B-202
# 58    ATAD3B  protein_coding          1  1483484  1496202      ATAD3B-205
# 69    ATAD3B  protein_coding          1  1484568  1496201      ATAD3B-204
#
#       transcript_biotype    transcript_id transcript_version  \
# 1         protein_coding  ENST00000673477                  1
# 38       retained_intron  ENST00000472194                  6
# 53  processed_transcript  ENST00000378736                  3
# 58       retained_intron  ENST00000485748                  5
# 69       retained_intron  ENST00000474481                  1
#
#                   tid transcript_biotype_clean
# 1   ENST00000673477.1           protein coding
# 38  ENST00000472194.6          retained intron
# 53  ENST00000378736.3     processed transcript
# 58  ENST00000485748.5          retained intron
# 69  ENST00000474481.1          retained intron

# %%
# load the nanocount data
fpath = "/scratch/indikar_root/indikar1/cstansbu/HSC/nanocount/merged/merged_tx_counts.tsv"
df = pd.read_csv(fpath, sep='\t')
print(f"{df.shape=}")
df = df.rename(columns={'transcript_name' : 'tid'})
df.head()
# Out:
# df.shape=(178136, 5)
#                   tid       raw     est_count           tpm  transcript_length
# 0   ENST00000368719.8  0.029819  1.424769e+06  29819.135395                665
# 1   ENST00000245185.5  0.019882  9.499839e+05  19882.314105                786
# 2  ENST00000331825.10  0.017566  8.392940e+05  17565.673653                878
# 3   ENST00000501597.3  0.016534  7.900110e+05  16534.224764                469
# 4   ENST00000496817.5  0.015537  7.423824e+05  15537.400447                673

# %%
# merge 'em
pdf = pd.merge(df, tdf, 
               how='left',
               left_on='tid',
               right_on='tid')

# drop unnamed genes
pdf = pdf[pdf['gene_name'].notna()]
pdf = pdf.sort_values(by=['gene_name', 'transcript_name'])

# add percent of total transcription
pdf['n_isoforms'] = pdf.groupby('gene_name')['transcript_name'].transform('nunique')
pdf['gene_tpm'] = pdf.groupby('gene_name')['tpm'].transform('sum')
pdf['tx_prc'] = pdf['tpm'] / pdf['gene_tpm']
pdf['tx_prc'] = pdf['tx_prc'].fillna(0)

print(f"{pdf.shape=}")
pdf.head()
# Out:
# pdf.shape=(127608, 18)
#                       tid           raw    est_count        tpm  \
# 1088    ENST00000595014.1  8.041462e-05  3842.238755  80.414625
# 73205   ENST00000596924.1  4.185821e-08     2.000000   0.041858
# 1092    ENST00000598345.1  8.012115e-05  3828.216344  80.121148
# 167271  ENST00000600966.1  0.000000e+00     0.000000   0.000000
# 92853   ENST00000282641.6  6.976369e-09     0.333333   0.006976
#
#         transcript_length gene_name    gene_biotype Chromosome       Start  \
# 1088                 2301      A1BG  protein_coding         19  58346857.0
# 73205                2134      A1BG  protein_coding         19  58345177.0
# 1092                  475      A1BG  protein_coding         19  58346859.0
# 167271                917      A1BG  protein_coding         19  58350593.0
# 92853                9350      A1CF  protein_coding         10  50799420.0
#
#                End transcript_name    transcript_biotype    transcript_id  \
# 1088    58353491.0        A1BG-202       retained_intron  ENST00000595014
# 73205   58347634.0        A1BG-203  processed_transcript  ENST00000596924
# 1092    58347657.0        A1BG-204       retained_intron  ENST00000598345
# 167271  58353129.0        A1BG-205        protein_coding  ENST00000600966
# 92853   50885675.0        A1CF-201        protein_coding  ENST00000282641
#
#        transcript_version transcript_biotype_clean  n_isoforms    gene_tpm  \
# 1088                    1          retained intron           4  160.577631
# 73205                   1     processed transcript           4  160.577631
# 1092                    1          retained intron           4  160.577631
# 167271                  1           protein coding           4  160.577631
# 92853                   6           protein coding           9    0.020929
#
#           tx_prc
# 1088    0.500783
# 73205   0.000261
# 1092    0.498956
# 167271  0.000000
# 92853   0.333333

# %%
outpath = "/nfs/turbo/umms-indikar/shared/projects/HSC/data/isoforms/HSC.nanocount.csv"
pdf.to_csv(outpath, index=False)
pdf.head()
# Out:
#                       tid           raw    est_count        tpm  \
# 1088    ENST00000595014.1  8.041462e-05  3842.238755  80.414625
# 73205   ENST00000596924.1  4.185821e-08     2.000000   0.041858
# 1092    ENST00000598345.1  8.012115e-05  3828.216344  80.121148
# 167271  ENST00000600966.1  0.000000e+00     0.000000   0.000000
# 92853   ENST00000282641.6  6.976369e-09     0.333333   0.006976
#
#         transcript_length gene_name    gene_biotype Chromosome       Start  \
# 1088                 2301      A1BG  protein_coding         19  58346857.0
# 73205                2134      A1BG  protein_coding         19  58345177.0
# 1092                  475      A1BG  protein_coding         19  58346859.0
# 167271                917      A1BG  protein_coding         19  58350593.0
# 92853                9350      A1CF  protein_coding         10  50799420.0
#
#                End transcript_name    transcript_biotype    transcript_id  \
# 1088    58353491.0        A1BG-202       retained_intron  ENST00000595014
# 73205   58347634.0        A1BG-203  processed_transcript  ENST00000596924
# 1092    58347657.0        A1BG-204       retained_intron  ENST00000598345
# 167271  58353129.0        A1BG-205        protein_coding  ENST00000600966
# 92853   50885675.0        A1CF-201        protein_coding  ENST00000282641
#
#        transcript_version transcript_biotype_clean  n_isoforms    gene_tpm  \
# 1088                    1          retained intron           4  160.577631
# 73205                   1     processed transcript           4  160.577631
# 1092                    1          retained intron           4  160.577631
# 167271                  1           protein coding           4  160.577631
# 92853                   6           protein coding           9    0.020929
#
#           tx_prc
# 1088    0.500783
# 73205   0.000261
# 1092    0.498956
# 167271  0.000000
# 92853   0.333333

# %%
break
# Out:
#   Cell In[8], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
test = pdf[pdf["gene_name"] == 'CASP1']
test

# %%
break

# %% [markdown]
# # look at FB genes

# %%
perc_lb = 0.2
perc_ub = 0.8

mgenes = markers[markers['Fib'] == 1]['gene_name'].values 
fdf = pdf[pdf['gene_name'].isin(mgenes)]
print(f"{fdf.shape=}")

fdf = fdf.sort_values(by='gene_tpm', ascending=False)

fdf.head(50)

# %%
query = 'HIF1A'

pdx = fdf[fdf['gene_name'] == query]
pdx = pdx.sort_values(by='transcript_name')


plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = 3, len(pdx) / 4
sns.barplot(data=pdx, 
            x='tx_prc',
            y='transcript_name',
            hue='transcript_biotype_clean',
            ec='k')

sns.despine(bottom=True)
plt.ylabel("")
plt.xlabel('Percent of Expression')
sns.move_legend(plt.gca(), 
                loc='upper right',
                title='Type',
                bbox_to_anchor=(2.3, 1))

# %% [markdown]
# # look at HSC genes

# %% [markdown]
# # look at repgromming TFs

# %%
gene_list = [
    'GATA2',
    'GFI1B',
    'FOS',
    'STAT5A',
    'REL',   
] 

fdf = pdf[pdf['gene_name'].isin(gene_list)]
fdf

# %%
query = 'GATA2'

pdx = fdf[fdf['gene_name'] == query]
pdx = pdx.sort_values(by='transcript_name')


plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = 3, len(pdx) / 4
sns.barplot(data=pdx, 
            x='tx_prc',
            y='transcript_name',
            hue='transcript_biotype_clean',
            ec='k')

sns.despine(bottom=True)
plt.ylabel("")
plt.xlabel('Percent of Expression')
sns.move_legend(plt.gca(), 
                loc='upper right',
                title='Type',
                bbox_to_anchor=(1.9, 1))
